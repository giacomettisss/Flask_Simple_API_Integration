# %%
import sqlite3
import requests

# %%
conn = sqlite3.connect('./data_base/database.db')
cursor = conn.cursor()
url_area = f'https://apisidra.ibge.gov.br/values/t/5457/n6/all/v/216/p/{2019}/c782/40124?formato=json'
url_producao = f'https://apisidra.ibge.gov.br/values/t/5457/n6/all/v/214/p/{2019}/c782/40124?formato=json'

response_area = requests.get(url_area).json()
response_producao = requests.get(url_producao).json()

# %%
response_producao
# Out:
# [{'NC': 'Nível Territorial (Código)',
#   'NN': 'Nível Territorial',
#   'MC': 'Unidade de Medida (Código)',
#   'MN': 'Unidade de Medida',
#   'V': 'Valor',
#   'D1C': 'Município (Código)',
#   'D1N': 'Município',
#   'D2C': 'Variável (Código)',
#   'D2N': 'Variável',
#   'D3C': 'Ano (Código)',
#   'D3N': 'Ano',
#   'D4C': 'Produto das lavouras temporárias e permanentes (Código)',
#   'D4N': 'Produto das lavouras temporárias e permanentes'},
#  {'NC': '6',
#   'NN': 'Município',
#   'MC': '1017',
#   'MN': 'Toneladas',
#   'V': '1350',
#   'D1C': '1100015',
#   'D1N': "Alta Floresta D'Oeste - RO",
#   'D2C': '214',
#   'D2N': 'Quantidade produzida',
#   'D3C': '2019',
#   'D3N': '2019',
#   'D4C': '40124',
#   'D4N': 'Soja (em grão)'},
#  {'NC': '6',
#   'NN': 'Município',
#   'MC': '1017',
#   'MN': 'Toneladas',
#   'V': '24592',
#   'D1C': '1100023',
#   'D1N': 'Ariquemes - RO',
#   'D2C': '214',
#   'D2N': 'Quantidade produzida',
#   'D3C': '2019',
#   'D3N': '2019',
# ...
